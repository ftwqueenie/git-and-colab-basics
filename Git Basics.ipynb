# %%
import pandas as pd

# %%
hello

# %% [markdown]
# === hello

# %%
##Jupyter notebook

# %%
df = pd.read_csv('DataSeerGrab.csv')

# %%
df.describe()
# Out:
#        pick_up_latitude  pick_up_longitude  drop_off_latitude  \
# count        300.000000         300.000000         300.000000
# mean          14.568170         121.045472          14.570122
# std            0.105709           0.050816           0.051373
# min           12.879721         120.972865          14.417032
# 25%           14.551893         121.024334          14.550883
# 50%           14.572160         121.042200          14.559313
# 75%           14.589131         121.061000          14.589908
# max           14.702179         121.774017          14.881480
#
#        drop_off_longitude        fare  pick_up_distance
# count          300.000000  300.000000        245.000000
# mean           121.032800  206.747917          1.265060
# std              0.031681  127.126511          0.988334
# min            120.867120    0.000000          0.031872
# 25%            121.017265  167.031250          0.484101
# 50%            121.027670  211.875000          1.009640
# ...

# %%
df.dropna()
# Out:
#     source     created_at_local  pick_up_latitude  pick_up_longitude  \
# 0      ADR  2013-09-22 23:46:18         14.604348         120.998654
# 1      T47   2013-11-04 3:51:59         14.590099         121.082645
# 2      T47   2013-11-21 5:21:24         14.582707         121.061458
# 3      ADR  2013-09-16 20:53:34         14.585812         121.060171
# 4      IOS  2013-09-10 23:49:16         14.552010         121.051260
# ..     ...                  ...               ...                ...
# 272    VNU  2013-11-16 17:36:24         14.549732         121.026770
# 273    VNU  2013-12-01 19:11:18         14.549732         121.026770
# 274    VNU  2013-12-22 19:55:25         14.549732         121.026770
# 275    IOS   2013-12-05 9:51:59         14.492170         121.042590
# 276    VNU  2013-12-13 22:00:10         14.549732         121.026770
#
#      drop_off_latitude  drop_off_longitude          city     fare  \
# 0            14.537370          120.994423  Metro Manila  281.875
# ...

# %%
df.to_csv('gitbasics_removedmissing.csv',index=False)

# %% [markdown]
# end
